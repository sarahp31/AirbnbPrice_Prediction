# %% [markdown]
# # Hypothesis Test

# %%
import pathlib
import pickle
import pandas as pd
import seaborn as sns

import utils

import numpy as np
from itertools import permutations

# %%
DATA_DIR = pathlib.Path.cwd().parent / 'data'
processed_file_path = DATA_DIR / 'processed' / 'amsterdam_coefficient.pkl'

with open(processed_file_path, 'rb') as file:
    (
        data_amsterdam,
        coeficientes_entireHouse_Amsterdam,
        coeficientes_privateRoom_Amsterdam,
    ) = pickle.load(file)

# %%
processed_file_path = DATA_DIR / 'processed' / 'athens_coefficient.pkl'

with open(processed_file_path, 'rb') as file:
    (
        data_atenas,
        coeficientes_entireHouse_Athens,
        coeficientes_privateRoom_Athens,
    ) = pickle.load(file)

# %%
processed_file_path = DATA_DIR / 'processed' / 'paris_coefficient.pkl'

with open(processed_file_path, 'rb') as file:
    (
        data_atenas,
        coeficientes_entireHouse_Paris,
        coeficientes_privateRoom_Paris,
    ) = pickle.load(file)

# %% [markdown]
# ## Permutation Test

# %%
fetures_EntireHouse = ['Person Capacity', 'Guest Satisfaction', 'Attraction Index', 'Restraunt Index']
fetures_PrivateRoom = ['Person Capacity', 'Guest Satisfaction', 'Attraction Index', 'Restraunt Index', 'City Center (km)']

# %% [markdown]
# #### Entire House/Apt: Amsterdam X Athens

# %%
utils.permutaionTeste_EntireHouse(fetures_EntireHouse, coeficientes_entireHouse_Amsterdam, coeficientes_entireHouse_Athens)
# Out:
# feuture Person Capacity: p-value = 0.000999000999000999
# feuture Guest Satisfaction: p-value = 0.000999000999000999
# feuture Attraction Index: p-value = 1.0
# feuture Restraunt Index: p-value = 1.0

# %% [markdown]
# #### Entire House/Apt: Amsterdam X Paris

# %%
utils.permutaionTeste_EntireHouse(fetures_EntireHouse, coeficientes_entireHouse_Amsterdam, coeficientes_entireHouse_Paris)
# Out:
# feuture Person Capacity: p-value = 1.0
# feuture Guest Satisfaction: p-value = 0.000999000999000999
# feuture Attraction Index: p-value = 1.0
# feuture Restraunt Index: p-value = 0.000999000999000999

# %% [markdown]
# #### Entire House/Apt: Paris X Athens

# %%
utils.permutaionTeste_EntireHouse(fetures_EntireHouse, coeficientes_entireHouse_Paris, coeficientes_entireHouse_Athens)
# Out:
# feuture Person Capacity: p-value = 0.000999000999000999
# feuture Guest Satisfaction: p-value = 1.0
# feuture Attraction Index: p-value = 0.000999000999000999
# feuture Restraunt Index: p-value = 1.0

# %% [markdown]
# #### Private Room: Amsterdam X Athens

# %%
utils.permutaionTeste_EntireHouse(fetures_PrivateRoom, coeficientes_privateRoom_Amsterdam, coeficientes_privateRoom_Athens)
# Out:
# feuture Person Capacity: p-value = 0.000999000999000999
# feuture Guest Satisfaction: p-value = 1.0
# feuture Attraction Index: p-value = 1.0
# feuture Restraunt Index: p-value = 1.0
# feuture City Center (km): p-value = 1.0

# %% [markdown]
# #### Private Room: Amsterdam X Paris

# %%
utils.permutaionTeste_EntireHouse(fetures_PrivateRoom, coeficientes_privateRoom_Amsterdam, coeficientes_privateRoom_Paris)
# Out:
# feuture Person Capacity: p-value = 0.000999000999000999
# feuture Guest Satisfaction: p-value = 1.0
# feuture Attraction Index: p-value = 1.0
# feuture Restraunt Index: p-value = 0.000999000999000999
# feuture City Center (km): p-value = 1.0

# %% [markdown]
# #### Private Room: Athens X Paris

# %%
utils.permutaionTeste_EntireHouse(fetures_PrivateRoom, coeficientes_privateRoom_Paris, coeficientes_privateRoom_Athens)
# Out:
# feuture Person Capacity: p-value = 0.000999000999000999
# feuture Guest Satisfaction: p-value = 1.0
# feuture Attraction Index: p-value = 0.000999000999000999
# feuture Restraunt Index: p-value = 1.0
# feuture City Center (km): p-value = 1.0
